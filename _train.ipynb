# %% [markdown]
# ## Training

# %%
# train all layers
# !python train.py \
--snapshot checkpoints/voc_piou_l3/pascal.h5 \
--snapshot-path checkpoints/voc_smoothpiou_finetuned_v2 \
--loss piou_smooth \
--regression_weight 2 \
--phi 0 \
--gpu 1 \
--epochs 100 \
--no-evaluation \
--random-transform \
--compute-val-loss \
--lr 1e-3 \
--batch-size 12 \
--use_tfrecords \
pascal /datasets/dataset/VOCdevkit/VOC2007
# Out:
# {'dataset_type': 'pascal', 'detect_quadrangle': False, 'detect_text': False, 'snapshot': 'checkpoints/voc_piou_l3/pascal.h5', 'freeze_backbone': False, 'freeze_bn': False, 'weighted_bifpn': False, 'lr': 0.001, 'batch_size': 12, 'phi': 0, 'gpu': '1', 'epochs': 100, 'steps': 10000, 'snapshot_path': 'checkpoints/voc_smoothpiou_finetuned_v2', 'tensorboard_dir': 'logs/2021-03-10', 'snapshots': True, 'evaluation': False, 'random_transform': True, 'compute_val_loss': True, 'loss': 'piou_smooth', 'regression_weight': 2.0, 'use_tfrecords': True, 'freeze_iterations': 0, 'multiprocessing': False, 'workers': 1, 'max_queue_size': 10, 'pascal_path': '/datasets/dataset/VOCdevkit/VOC2007'}
# Loading model, this may take a second...
# Epoch 1/100
# 418/418 [==============================] - ETA: 0s - loss: 0.7374 - classification_loss: 0.3645 - regression_loss: 0.3729
# Epoch 00001: val_loss improved from inf to 0.69903, saving model to checkpoints/voc_smoothpiou_finetuned_v2/pascal.h5
# ...
